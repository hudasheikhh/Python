# %%
import pandas as pd
# Out:
# C:\Users\HUDA\AppData\Local\Temp\ipykernel_18680\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("C:/Users/HUDA/OneDrive/Desktop/Python/archive/pokemon.csv")
df
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
#Relative Path

df = pd.read_csv("../archive/pokemon.csv")
df
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
df.dtypes
# Out:
# abilities             object
# against_bug          float64
# against_dark         float64
# against_dragon       float64
# against_electric     float64
# against_fairy        float64
# against_fight        float64
# against_fire         float64
# against_flying       float64
# against_ghost        float64
# against_grass        float64
# against_ground       float64
# against_ice          float64
# against_normal       float64
# against_poison       float64
# against_psychic      float64
# against_rock         float64
# against_steel        float64
# against_water        float64
# attack                 int64
# base_egg_steps         int64
# base_happiness         int64
# base_total             int64
# capture_rate          object
# classfication         object
# defense                int64
# experience_growth      int64
# height_m             float64
# hp                     int64
# japanese_name         object
# name                  object
# percentage_male      float64
# ...

# %%
df.shape # to see row and column count
# Out:
# (801, 41)

# %%
df.describe()
# Out:
#        against_bug  against_dark  against_dragon  against_electric  \
# count   801.000000    801.000000      801.000000        801.000000
# mean      0.996255      1.057116        0.968789          1.073970
# std       0.597248      0.438142        0.353058          0.654962
# min       0.250000      0.250000        0.000000          0.000000
# 25%       0.500000      1.000000        1.000000          0.500000
# 50%       1.000000      1.000000        1.000000          1.000000
# 75%       1.000000      1.000000        1.000000          1.000000
# max       4.000000      4.000000        2.000000          4.000000
#
#        against_fairy  against_fight  against_fire  against_flying  \
# count     801.000000     801.000000    801.000000      801.000000
# mean        1.068976       1.065543      1.135456        1.192884
# std         0.522167       0.717251      0.691853        0.604488
# min         0.250000       0.000000      0.250000        0.250000
# ...

# %%
df[600:700]
# Out:
#                                     abilities  against_bug  against_dark  \
# 600           ['Plus', 'Minus', 'Clear Body']          0.5           1.0
# 601                              ['Levitate']          1.0           1.0
# 602                              ['Levitate']          1.0           1.0
# 603                              ['Levitate']          1.0           1.0
# 604  ['Telepathy', 'Synchronize', 'Analytic']          2.0           2.0
# ..                                        ...          ...           ...
# 695                  ['Strong Jaw', 'Sturdy']          1.0           1.0
# 696               ['Strong Jaw', 'Rock Head']          1.0           1.0
# 697           ['Refrigerate', 'Snow Warning']          1.0           1.0
# 698           ['Refrigerate', 'Snow Warning']          1.0           1.0
# 699                ['Cute Charm', 'Pixilate']          0.5           0.5
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# ...

# %%
#loc -- puts particular name in a column
df.loc[600:700,['abilities']]   # give list for multiple row

# iloc
df.iloc[600:700, 0:4]
# Out:
#                                     abilities  against_bug  against_dark  \
# 600           ['Plus', 'Minus', 'Clear Body']          0.5           1.0
# 601                              ['Levitate']          1.0           1.0
# 602                              ['Levitate']          1.0           1.0
# 603                              ['Levitate']          1.0           1.0
# 604  ['Telepathy', 'Synchronize', 'Analytic']          2.0           2.0
# ..                                        ...          ...           ...
# 695                  ['Strong Jaw', 'Sturdy']          1.0           1.0
# 696               ['Strong Jaw', 'Rock Head']          1.0           1.0
# 697           ['Refrigerate', 'Snow Warning']          1.0           1.0
# 698           ['Refrigerate', 'Snow Warning']          1.0           1.0
# 699                ['Cute Charm', 'Pixilate']          0.5           0.5
#
#      against_dragon
# 600             0.5
# 601             1.0
# 602             1.0
# ...

# %%
df.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
filtered_pokemon = df[(df['hp'] > 100) &  (df['type2'] == 'fire')].head(5)

print(filtered_pokemon)


#df.query("type2=='fire' and `hp`>100")
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 554  ['Sheer Force', 'Zen Mode']          0.5           1.0             1.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 554               1.0            0.5            1.0           0.5
#
#      against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# 554             1.0            1.0  ...             50.0             555
#
#      sp_attack  sp_defense  speed  type1  type2  weight_kg  generation  \
# 554        140         105     55   fire   fire       92.9           5
#
#      is_legendary
# 554             0
#
# [1 rows x 41 columns]

# %%
filtered_speed = df[(df['speed'] <= 10)] 
print(filtered_speed)
# Out:
#                                          abilities  against_bug  against_dark  \
# 212             ['Sturdy', 'Gluttony', 'Contrary']          1.0           1.0
# 327  ['Hyper Cutter', 'Arena Trap', 'Sheer Force']          1.0           1.0
# 437             ['Sturdy', 'Rock Head', 'Rattled']          1.0           1.0
# 445            ['Pickup', 'Thick Fat', 'Gluttony']          1.0           1.0
# 596                                 ['Iron Barbs']          1.0           1.0
# 770                     ['Innards Out', 'Unaware']          1.0           1.0
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# 212             1.0               1.0            1.0            1.0
# 327             1.0               0.0            1.0            1.0
# 437             1.0               1.0            1.0            2.0
# 445             1.0               1.0            1.0            2.0
# 596             0.5               0.5            0.5            2.0
# ...

# %%
legendary_pokemon = df[(df['is_legendary'] == 1)] 
print(legendary_pokemon)
# Out:
#                       abilities  against_bug  against_dark  against_dragon  \
# 143  ['Pressure', 'Snow Cloak']         0.50           1.0             1.0
# 144      ['Pressure', 'Static']         0.50           1.0             1.0
# 145  ['Pressure', 'Flame Body']         0.25           1.0             1.0
# 149     ['Pressure', 'Unnerve']         2.00           2.0             1.0
# 150             ['Synchronize']         2.00           2.0             1.0
# ..                          ...          ...           ...             ...
# 796             ['Beast Boost']         0.25           1.0             0.5
# 797             ['Beast Boost']         1.00           1.0             0.5
# 798             ['Beast Boost']         2.00           0.5             2.0
# 799             ['Prism Armor']         2.00           2.0             1.0
# 800              ['Soul-Heart']         0.25           0.5             0.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# ...

# %%
df.query("`is_legendary` == 1 and sp_defense>150")

df.loc[(df['is_legendary'] == 1) & (df['sp_defense'] > 150)]
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 248   ['Pressure', 'Multiscale']         1.00           2.0             1.0
# 249  ['Pressure', 'Regenerator']         0.25           1.0             1.0
# 377   ['Clear Body', 'Ice Body']         1.00           1.0             1.0
# 381                  ['Drizzle']         1.00           1.0             1.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 248               2.0            1.0           0.25           1.0
# 249               2.0            0.5           0.50           0.5
# 377               1.0            1.0           2.00           2.0
# 381               2.0            1.0           1.00           0.5
#
#      against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# 248             1.0            2.0  ...              NaN             249
# 249             1.0            1.0  ...              NaN             250
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %%
df.info(verbose=True)  # Verbose ---vExtra information

df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %%
df[1:10]
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 1  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3     ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4     ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 5     ['Blaze', 'Solar Power']         0.25           1.0             1.0
# 6     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 7     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 8     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 9  ['Shield Dust', 'Run Away']         1.00           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# ...

# %%
df.hp.apply(lambda x:x>60)
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 796     True
# 797    False
# 798     True
# 799     True
# 800     True
# Name: hp, Length: 801, dtype: bool

# %%
df.type1.map({'fire':'water45','water':'fire34'}).values
# Out:
# array([nan, nan, nan, 'water45', 'water45', 'water45', 'fire34', 'fire34',
#        'fire34', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, 'water45', 'water45', nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, 'fire34', 'fire34',
#        nan, nan, 'water45', 'water45', 'fire34', 'fire34', 'fire34', nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, 'fire34', 'fire34', nan,
#        nan, nan, 'water45', 'water45', 'fire34', 'fire34', nan, nan, nan,
#        nan, nan, 'fire34', 'fire34', nan, nan, 'fire34', 'fire34', nan,
#        nan, nan, nan, nan, nan, 'fire34', 'fire34', nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        'fire34', 'fire34', 'fire34', 'fire34', 'fire34', 'fire34', nan,
#        nan, nan, nan, 'water45', nan, nan, 'fire34', 'fire34', 'fire34',
# ...

# %%
df.hp.apply(lambda x:x+500)
# Out:
# 0      545
# 1      560
# 2      580
# 3      539
# 4      558
#       ...
# 796    597
# 797    559
# 798    723
# 799    597
# 800    580
# Name: hp, Length: 801, dtype: int64

# %%
df[df['hp'] > 100].groupby('type1')['hp'].aggregate(['max', 'min'])
# Out:
#           max  min
# type1
# bug       107  107
# dark      223  110
# dragon    216  105
# fairy     126  101
# fighting  144  105
# fire      115  105
# ghost     150  150
# grass     123  114
# ground    115  105
# ice       110  110
# normal    255  103
# poison    105  103
# psychic   190  106
# rock      123  109
# water     170  105

# %%
df[df['hp'] > 100].groupby(by=['type1'])['hp'].describe()

df[df['hp'] > 100].groupby(by=['type1'])['hp'].describe().aggregate(['min','max'])
# Out:
#      count   mean        std    min    25%    50%    75%    max
# min    1.0  104.0   0.000000  101.0  103.5  104.0  104.5  105.0
# max   14.0  153.0  61.147363  150.0  150.0  150.0  174.5  255.0

# %%
df.groupby(by=['type1'])['hp'].describe()
# Out:
#           count       mean        std   min    25%   50%    75%    max
# type1
# bug        72.0  56.722222  17.652532   1.0  45.00  60.0  70.00  107.0
# dark       29.0  72.551724  36.063026  35.0  52.00  65.0  75.00  223.0
# dragon     27.0  79.851852  34.962291  41.0  59.50  75.0  93.00  216.0
# electric   39.0  60.512821  17.519721  20.0  47.50  60.0  70.00   90.0
# fairy      18.0  73.944444  23.048471  35.0  56.25  76.0  88.75  126.0
# fighting   28.0  71.428571  26.790585  30.0  50.00  70.0  86.25  144.0
# fire       52.0  68.730769  19.182422  38.0  58.00  65.0  78.50  115.0
# flying      3.0  68.000000  24.433583  40.0  59.50  79.0  82.00   85.0
# ghost      27.0  63.370370  30.011726  20.0  45.00  59.0  67.00  150.0
# grass      78.0  65.358974  18.721454  30.0  50.00  65.0  75.00  123.0
# ground     32.0  73.187500  25.518415  10.0  56.75  72.5  91.25  115.0
# ice        23.0  72.086957  21.760918  36.0  53.00  70.0  90.00  110.0
# ...

# %%
pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.8.3-cp311-cp311-win_amd64.whl.metadata (5.9 kB)
# ...
#   Using cached contourpy-1.2.0-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.49.0-cp311-cp311-win_amd64.whl.metadata (162 kB)
# ...
#   Using cached kiwisolver-1.4.5-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# ...
#   Using cached pillow-10.2.0-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# ...
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# ...
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/7.6 MB 573.4 kB/s eta 0:00:14
#     --------------------------------------- 0.1/7.6 MB 658.7 kB/s eta 0:00:12
#    - -------------------------------------- 0.2/7.6 MB 787.7 kB/s eta 0:00:10
# ...

# %%
df.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
df.loc[:,['base_total']]
# Out:
#      base_total
# 0           318
# 1           405
# 2           625
# 3           309
# 4           405
# ..          ...
# 796         570
# 797         570
# 798         570
# 799         600
# 800         600
#
# [801 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.hist(df['base_total'], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Base Total Stats')
plt.ylabel('Frequency')
plt.title('Histogram of Pokémon Base Total Stats')
plt.show()

# %%
plt.scatter(df['attack'], df['defense'], color='orange', alpha=0.5)
plt.xlabel('Attack')
plt.ylabel('Defense')
plt.title('Pokémon Attack vs. Defense')
plt.show()
