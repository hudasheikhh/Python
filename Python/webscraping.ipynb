# %% [markdown]
# # WEBSCRAPING BEAUTIFULSOUP

# %%
from bs4 import BeautifulSoup
with open('index.html', 'r') as f:
    web_data = f.read()
# print(web_data)
    
soup = BeautifulSoup(web_data,'lxml')

# print(soup.prettify())

# soup.title   ---- object.tag name to see specific tag

# soup.find('h1')  

# soup.find('p',class_ = 'first')
# soup.find('p',class_ = 'second')

# soup.find_all('p').

# soup.find('p').text

mult=soup.find_all('p')
for val in mult:
    print(val.text)
# Out:
#  Hello, this is a basic HTML page!
# WebScraping BeautifulSoup
# © 2024 Your Website Name. All rights reserved.

# %%
from bs4 import BeautifulSoup

import requests
web_url=requests.get("https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords=Python+&txtLocation=mumbai").text
soup = BeautifulSoup(web_url,'lxml') 

# h2_tag = soup.find_all('h2')

li_tag = soup.find_all('li', class_='clearfix job-bx wht-shd-bx')
print(li_tag)
# Out:
# [<li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/python-developer-ltimindtree-ltd-mumbai-4-to-9-yrs-jobid-LGeknY79__SLASH__cBzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69816026','python3  ,  Object Oriented Analysis  ,  Design Patterns  ,  GIT  ,  jenkins','Mumbai','4 - 9','IT Software : Software Products &amp; Services','1','' )" target="_blank">
# <strong class="blkclor">Python</strong> Developer</a> </h2>
# <h3 class="joblist-comp-name">
#     LTIMindtree Ltd.
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=8NqVm__PLUS__d__PLUS__eSBzpSvf__PLUS__uAgZw==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>4 - 9 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# ...

# %%
# print(soup.prettify())

# for data in h2_tag:
    # print(data.text)

# for data in li_tag:
   # print(data.h2.text)

for data in li_tag:
     print(f"Designation :{data.h2.text.strip()}")
    # print(data.name)
    # print(data.attrs.keys())
# Out:
# Designation :Python Developer
# Designation :Python Developer
# Designation :Python Developer
# Designation :RASA / python Developer
# Designation :Full-Stack Developer - Python
# Designation :SDE 3 - Python
# Designation :Senior Python Developer
# Designation :Engineering Manager - Python / Golang / Nodejs
# Designation :Senior Engineering Manager - Python /  Golang /  Nodejs
# Designation :Full Stack Python Developer - L2
# Designation :CrimsonAI - Associate Architect - Python /  Node.Js /  Golang
# Designation :CrimsonAI - Architect - Python /  Node.Js /  Golang
# Designation :Data Scientist - ML ,  Python ,  AWS / Azure - 4-7 years -
# Designation :Crimson AI - Principal Engineer - Python /  Node.Js /  Golang
# Designation :DevOps Engineer
# Designation :AWS Developer
# Designation :SDE 1 /  SDE 2 /  SDE 3
# Designation :Developer , Specialised Technologies
# Designation :Senior Business Analyst / Data Engineer - Python  &  Cloud Computing
# Designation :Front-end Engineer
# ...

# %%
with open('designation.txt', 'x') as f:
    f.write('Create a designation text file!')

# %%
import os.path
print(os.path.exists('designation.txt'))
from pathlib import Path
path = Path('designation.txt')
print(path.is_file())
# Out:
# True
# True
